# %%
# CMD using in Terminal using databricks CLI
# databricks fs cp Version\ Info.py dbfs:/mnt/uploads/info.py --overwrite

# %%
# %fs ls 'dbfs:/mnt/uploads'

# %%
dbutils.secrets.help()

# %%
# CMD used to create a scope and also a password inside the scope
# databricks secrets create-scope --scope bookstore-dev
# databricks secrets put --scope bookstore-dev --key db_password --string-value 12345
# databricks secrets list --scope bookstore-dev

# %%
print(dbutils.secrets.get("bookstore-dev", "db_password"))

# %%
db_password = dbutils.secrets.get("bookstore-dev", "db_password")
for char in db_password:
    print(char, end=' ')
